# %% [markdown]
# <a href="https://colab.research.google.com/github/CesarRoldan99/CEE88_Cesar/blob/main/LAB4/my_recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Libraries 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math

# %%
# Reading data

df = pd.read_csv("https://raw.githubusercontent.com/albanda/CE888/master/lab4-recommender/jester-data-1.csv")

df.iloc[3343,5]
# Out:
# 2.04

# %%
#Making a copy

df_copy = df.copy()
df_copy

# Eliminationg first column

df_copy = df_copy.drop(columns="74")

# %%
# Best Joke

a = df_copy.mean()
print(a)
print(a.max())

print(a.idxmax())
# Out:
# -7.82    34.403125
# 8.79     27.094822
# -9.66    33.265435
# -8.16    36.246713
# -7.52     0.427554
#            ...
# 99.22    58.539484
# -5.63    58.019793
# 99.23    57.059971
# 99.24    55.751626
# 99.25    60.136534
# Length: 100, dtype: float64
# 65.5104066928187
# 99.1

# %%
# Worst Joke

print(a.min())

print(a.idxmin())
# Out:
# -3.071944199823859
# -7.52.1

# %%
# Helpers function

def replace(orig, percentage=0.1):
  """
  Replaces 'percentage'% of the original values in 'orig' with 99's
  :param orig: original data array
  :param percentage: percentage of values to replace (0<percentage<1)
  """
  new_data = orig.copy()
  rated = np.where(new_data!=99)
  n_rated = len(rated[0])
  idx = np.random.choice(n_rated, size=int(percentage*n_rated), replace=False)
  new_data[rated[0][idx], rated[1][idx]] = 99
  return new_data, (rated[0][idx], rated[1][idx])

# %%
# Using helpers function

arr = df_copy.values

new_arr, indx = replace(arr, 0.1)
new_arr = np.where(new_arr==99,np.nan,new_arr)

print(new_arr)
print(indx)
# Out:
# [[ 4.08 -0.29  6.36 ...  0.34 -4.32  1.07]
#  [99.   99.   99.   ... 99.   99.   99.  ]
#  [99.    8.35 99.   ... 99.   99.   99.  ]
#  ...
#  [99.   99.   99.   ... 99.   99.   99.  ]
#  [99.   99.   99.   ... 99.   99.   99.  ]
#  [ 2.43  2.67 -3.98 ... 99.   99.   99.  ]]
# [[ 4.08 -0.29  6.36 ...  0.34 -4.32  1.07]
#  [  nan   nan   nan ...   nan   nan   nan]
#  [  nan  8.35   nan ...   nan   nan   nan]
#  ...
#  [  nan   nan   nan ...   nan   nan   nan]
#  [  nan   nan   nan ...   nan   nan   nan]
#  [ 2.43  2.67 -3.98 ...   nan   nan   nan]]
# (array([ 4338,  5379,   210, ..., 16830, 22433, 23838]), array([61, 62, 26, ..., 88, 50, 35]))

# %%
# Latent Factors

n_latent_factors = 4

user_ratings = new_arr
# Initialise as random values
latent_user_preferences = np.random.random((user_ratings.shape[0], n_latent_factors))
latent_item_features = np.random.random((user_ratings.shape[1], n_latent_factors))

# %%
latent_item_features

# %%
latent_user_preferences

# %%
def predict_rating(user_id, item_id):
    """ Predict a rating given a user_id and an item_id.
    """
    user_preference = latent_user_preferences[user_id]
    item_preference = latent_item_features[item_id]
    return user_preference.dot(item_preference)


def train(user_id, item_id, rating, alpha=0.0001):
    #print(item_id)
    predicted_rating = predict_rating(user_id, item_id)
    err =  predicted_rating - rating
    #print(err)
    user_pref_values = latent_user_preferences[user_id]
    latent_user_preferences[user_id] -= alpha * err * latent_item_features[item_id]
    latent_item_features[item_id] -= alpha * err * user_pref_values
    return err
    

def sgd(iterations):
    """ Iterate over all users and all items and train for 
        a certain number of iterations
    """
    mse_history = []
    for iteration in range(iterations):
        error = []
        for user_id in range(latent_user_preferences.shape[0]):
            for item_id in range(latent_item_features.shape[0]):
                rating = user_ratings[user_id, item_id]
                if not np.isnan(rating):
                    err = train(user_id, item_id, rating)
                    error.append(err)
        mse = (np.array(error) ** 2).mean()   
        if (iteration % 10) == 0:
            print('Iteration %d/%d:\tMSE=%.6f' % (iteration, iterations, mse))
            mse_history.append(mse)
    return mse_history

# %%
num_iter = 100
hist = sgd(num_iter)  # Note how the MSE decreases with the number of iterations
plt.figure()
plt.plot(np.arange(0, num_iter, 10), hist)
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.show()
# Out:
# Iteration 0/100:	MSE=15.975426
# Iteration 10/100:	MSE=15.731787
# Iteration 20/100:	MSE=15.547778
# Iteration 30/100:	MSE=15.424485
# Iteration 40/100:	MSE=15.344979
# Iteration 50/100:	MSE=15.293282
# Iteration 60/100:	MSE=15.258872
# Iteration 70/100:	MSE=15.235413
# Iteration 80/100:	MSE=15.219093
# Iteration 90/100:	MSE=15.207563

# %%
predictions = latent_user_preferences.dot(latent_item_features.T)
predictions
# Out:
# array([[ 2.24419206,  3.97210127,  4.82835266, ...,  5.01313513,
#          3.94110817,  5.68440488],
#        [ 6.97195861,  6.38103541,  7.03705796, ...,  6.36479044,
#          7.34513918,  7.13375034],
#        [ 2.06496719,  5.05536614,  3.30093535, ...,  5.27911527,
#         -1.45637406,  6.58654164],
#        ...,
#        [-0.30277204,  2.06675975,  1.02449654, ...,  2.24428383,
#         -2.16255282,  2.93798315],
#        [-1.06539053,  0.16638537, -2.0252796 , ..., -0.7421334 ,
#         -5.36724896, -0.32178564],
#        [ 1.49432028,  1.01126596,  1.93644775, ...,  4.5964064 ,
#          3.83650332,  4.86291158]])

# %%
values = [zip(user_ratings[i], predictions[i]) for i in range(predictions.shape[0])]
comparison_data = pd.DataFrame(values)
comparison_data.columns = df_copy.columns

# %%
comparison_data
# For each data point, the number on the left is the original value from the dataset, the number on the right is the prediction
# Out:
#                              -7.82  ...                       99.25
# 0        (4.08, 2.244192060127031)  ...   (1.07, 5.684404884330197)
# 1         (nan, 6.971958606987551)  ...    (nan, 7.133750339582113)
# 2        (nan, 2.0649671866427664)  ...    (nan, 6.586541638471704)
# 3        (8.5, 2.6762425230165623)  ...    (nan, 5.759003382561909)
# 4      (-6.17, -4.190315490373088)  ...   (nan, -6.094716096410665)
# ...                            ...  ...                         ...
# 24977   (0.44, 0.5083072735658937)  ...  (7.43, 6.3807505453998825)
# 24978    (nan, 1.8939920975950226)  ...   (8.45, 3.358849002867407)
# 24979   (nan, -0.3027720443455384)  ...    (nan, 2.937983154434712)
# 24980   (nan, -1.0653905255311775)  ...  (nan, -0.3217856386264974)
# 24981   (2.43, 1.4943202817522194)  ...    (nan, 4.862911582831941)
#
# [24982 rows x 100 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-551885eb-8e28-458e-bd35-3dc336740418" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-551885eb-8e28-458e-bd35-3dc336740418">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving movies_latent_factors.xlsx to movies_latent_factors.xlsx

# %%
# Reading movies data
import io
df_movies_users = pd.read_excel(io.BytesIO(uploaded['movies_latent_factors.xlsx']),sheet_name="Users",index_col="User")
df_movies_users
# Out:
#        Factor1   Factor2   Factor3  ...  Factor13  Factor14  Factor15
# User                                ...
# 4768 -0.204024  0.161079 -0.090447  ...  0.007108 -0.118663 -0.039125
# 156  -0.189652 -0.178979 -0.091490  ...  0.045916  0.113671  0.179873
# 5323 -0.115308 -0.090886 -0.053129  ...  0.108372  0.054471 -0.109552
# 174  -0.227462 -0.272532 -0.017231  ...  0.036767 -0.165438  0.050692
# 4529 -0.014616 -0.102218 -0.107935  ... -0.039897  0.129063  0.102669
# 783  -0.020301 -0.031919 -0.036955  ... -0.021647  0.039873 -0.061857
# 3878 -0.091462  0.215879 -0.180453  ...  0.189250  0.065990  0.102776
# 768   0.000819 -0.009229 -0.019228  ... -0.002108  0.043223 -0.006670
# 4469 -0.030528 -0.011537 -0.042822  ...  0.024400  0.005318 -0.007983
# 1882 -0.083093 -0.029160  0.013748  ... -0.021325  0.181508  0.022357
# 4997 -0.185443 -0.276496 -0.781275  ... -0.100563  0.100164  0.043196
# 2067 -0.083242  0.181171 -0.344267  ...  0.176661 -0.055812 -0.000042
# ...

# %%
df_movies_Items = pd.read_excel(io.BytesIO(uploaded['movies_latent_factors.xlsx']),sheet_name="Items",index_col="Movie ID")
df_movies_Items_copy =df_movies_Items.copy()
df_movies_Items_copy = df_movies_Items_copy.drop(columns="Title")
df_movies_Items_copy
# Out:
#            Factor1   Factor2   Factor3  ...  Factor13  Factor14  Factor15
# Movie ID                                ...
# 11       -1.521848 -1.038507  2.027269  ...  0.403861  1.129616 -0.248806
# 12       -0.342185 -0.296586 -0.385962  ... -0.564415  0.506876  1.274993
# 13       -2.240888 -0.438815 -2.275177  ... -0.330276 -2.209004 -0.419092
# 14       -0.634531  2.186059 -0.066681  ... -0.819682  0.549010 -0.681191
# 22        0.517348 -1.456763  0.369161  ...  1.429191  0.855746 -2.292566
# ...            ...       ...       ...  ...       ...       ...       ...
# 9806      0.159967 -0.051123  0.311183  ... -0.649164  0.045580  1.017861
# 10020     1.286288  0.004957 -0.157640  ...  0.994535  0.868700 -0.487076
# 36657     0.811901 -0.893280  0.668953  ...  0.642105 -1.355542  0.067790
# 36658     1.161006 -0.715613  0.712633  ...  0.290714 -1.217250 -0.288130
# 36955     1.734008  0.265436 -0.003391  ...  0.333703 -0.223382 -0.022599
#
# [100 rows x 15 columns]

# %%
a = df_movies_users.loc[783]
print(a)
b = df_movies_Items_copy.loc[2024]
print(b)
# Out:
# Factor1    -0.020301
# Factor2    -0.031919
# Factor3    -0.036955
# Factor4     0.033690
# Factor5     0.000174
# Factor6    -0.003178
# Factor7     0.054474
# Factor8     0.045424
# Factor9    -0.053308
# Factor10    0.003437
# Factor11   -0.041750
# Factor12    0.059725
# Factor13   -0.021647
# Factor14    0.039873
# Factor15   -0.061857
# Name: 783, dtype: float64
# Factor1     1.087832
# Factor2    -0.497786
# Factor3    -1.038099
# Factor4    -0.295358
# Factor5     0.975285
# Factor6    -0.081090
# Factor7    -0.282453
# Factor8     0.126386
# Factor9    -0.166706
# Factor10    0.834347
# Factor11   -0.887381
# Factor12    0.498102
# Factor13    0.643096
# Factor14   -0.352181
# Factor15    0.032328
# Name: 2024, dtype: float64

# %%
def predict_rating(user_id, item_id):
    """ Predict a rating given a user_id and an item_id.
    """
    user_preference = df_movies_users.loc[user_id]
    item_preference = df_movies_Items_copy.loc[item_id]
    return user_preference.dot(item_preference)

r = predict_rating(3519,786)
print(r)
# Out:
# 0.0674203256123457

# %%
r1 = predict_rating(4529,581)
print(r1)

# %%
df_movies_Items.loc[[664],["Factor15"]]
# Out:
#           Factor15
# Movie ID
# 664       0.798033

# %%
q=[]
d = { }
for i in df_movies_Items_copy.index:
    q.append(predict_rating(4469,i))
    d[predict_rating(4469,i)] =  i

q.sort()
x=[d.get(q.pop(-1)),d.get(q.pop(-1))]
print(x)
# Out:
# [278, 453]

# %%
q=[]
d = { }
for i in df_movies_Items_copy.index:
    q.append(predict_rating(1882,i))
    d[predict_rating(1882,i)] =  i

q.sort()
x=[d.get(q.pop(-1)),d.get(q.pop(-1)),d.get(q.pop(-1))]
print(x)

df_movies_Items.loc[x]
# Out:
# [604, 603, 597]
#                                Title   Factor1  ...  Factor14  Factor15
# Movie ID                                        ...
# 604       The Matrix Reloaded (2003)  0.503414  ...  0.748458  2.120907
# 603                The Matrix (1999) -3.063639  ...  0.223797  0.752413
# 597                   Titanic (1997)  1.567865  ...  2.215933  0.456127
#
# [3 rows x 16 columns]
